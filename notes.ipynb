# %% [markdown]
# # To Do

# %% [markdown]
# # Ideas to Explore
#
# - correct for degree and other topological confounders
# - identify key models to compare our method to
# - simulate the model
# - explore the asymptotics of the method
# - are Betti numbers approximately normal?
# - minimize Betti numbers by maximizing Hodge Laplacian ranks
# - heuristically approximate minimizing Betti numbers by destroying edges that belong to the fewest simplices

# %% [markdown]
# # Key Problems
#
# - Confounders (e.g. degree and other topological covariates)
# - Non-discretized test statistic
# - Numerical stability of Mahalanobis distance
# - Addressing how appropriate a simplicial complex representation is
# - Throwing out hetergeneous edges
